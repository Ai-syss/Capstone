# %% [markdown]
# this notebook will be mainly used for the capstone project.

# %%
import numpy as np  
import pandas as pd

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %%
df= pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/748584/1294786/2020.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20201001%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20201001T060821Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...', index_col=0)
df.head()
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Finland          Western Europe        7.8087                        0.031156
# Denmark          Western Europe        7.6456                        0.033492
# Switzerland      Western Europe        7.5599                        0.035014
# Iceland          Western Europe        7.5045                        0.059616
# Norway           Western Europe        7.4880                        0.034837
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Finland           7.869766      7.747634              10.639267
# Denmark           7.711245      7.579955              10.774001
# Switzerland       7.628528      7.491272              10.979933
# Iceland           7.621347      7.387653              10.772559
# Norway            7.556281      7.419719              11.087804
#
#               Social support  Healthy life expectancy  \
# Country name
# ...

# %%
hap=df.drop(['Standard error of ladder score','upperwhisker','lowerwhisker','Explained by: Log GDP per capita','Explained by: Social support','Explained by: Healthy life expectancy','Explained by: Freedom to make life choices','Explained by: Generosity','Explained by: Perceptions of corruption','Dystopia + residual','Ladder score in Dystopia'], axis=1)
hap.head()
# Out:
#              Regional indicator  Ladder score  Logged GDP per capita  \
# Country name
# Finland          Western Europe        7.8087              10.639267
# Denmark          Western Europe        7.6456              10.774001
# Switzerland      Western Europe        7.5599              10.979933
# Iceland          Western Europe        7.5045              10.772559
# Norway           Western Europe        7.4880              11.087804
#
#               Social support  Healthy life expectancy  \
# Country name
# Finland             0.954330                71.900825
# Denmark             0.955991                72.402504
# Switzerland         0.942847                74.102448
# Iceland             0.974670                73.000000
# Norway              0.952487                73.200783
#
#               Freedom to make life choices  Generosity  \
# Country name
# Finland                           0.949172   -0.059482
# Denmark                           0.951444    0.066202
# ...

# %%
hap[:5]
# Out:
#              Regional indicator  Ladder score  Logged GDP per capita  \
# Country name
# Finland          Western Europe        7.8087              10.639267
# Denmark          Western Europe        7.6456              10.774001
# Switzerland      Western Europe        7.5599              10.979933
# Iceland          Western Europe        7.5045              10.772559
# Norway           Western Europe        7.4880              11.087804
#
#               Social support  Healthy life expectancy  \
# Country name
# Finland             0.954330                71.900825
# Denmark             0.955991                72.402504
# Switzerland         0.942847                74.102448
# Iceland             0.974670                73.000000
# Norway              0.952487                73.200783
#
#               Freedom to make life choices  Generosity  \
# Country name
# Finland                           0.949172   -0.059482
# Denmark                           0.951444    0.066202
# ...

# %%
hap.rename(columns={'Ladder score':'Happiness score'}, inplace=True)
hap.head()
# Out:
#              Regional indicator  Happiness score  Logged GDP per capita  \
# Country name
# Finland          Western Europe           7.8087              10.639267
# Denmark          Western Europe           7.6456              10.774001
# Switzerland      Western Europe           7.5599              10.979933
# Iceland          Western Europe           7.5045              10.772559
# Norway           Western Europe           7.4880              11.087804
#
#               Social support  Healthy life expectancy  \
# Country name
# Finland             0.954330                71.900825
# Denmark             0.955991                72.402504
# Switzerland         0.942847                74.102448
# Iceland             0.974670                73.000000
# Norway              0.952487                73.200783
#
#               Freedom to make life choices  Generosity  \
# Country name
# Finland                           0.949172   -0.059482
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df_can=hap.iloc[:,:2].head(20)

df_can
# Out:
#                           Regional indicator  Happiness score
# Country name
# Finland                       Western Europe           7.8087
# Denmark                       Western Europe           7.6456
# Switzerland                   Western Europe           7.5599
# Iceland                       Western Europe           7.5045
# Norway                        Western Europe           7.4880
# Netherlands                   Western Europe           7.4489
# Sweden                        Western Europe           7.3535
# New Zealand            North America and ANZ           7.2996
# Austria                       Western Europe           7.2942
# Luxembourg                    Western Europe           7.2375
# Canada                 North America and ANZ           7.2321
# Australia              North America and ANZ           7.2228
# United Kingdom                Western Europe           7.1645
# Israel          Middle East and North Africa           7.1286
# ...

# %% [markdown]
# ## Data Visualization

# %%
df_can.plot(kind='bar', figsize=(10, 5))

plt.title('Happiness score of Top 20 countries') # add title to the plot

            
plt.show()

# %%
# !conda install -c anaconda seaborn --yes

# import library
import seaborn as sns

print('Seaborn installed and imported!')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Seaborn installed and imported!

# %%
import seaborn as sns
ax = sns.regplot(x='Happiness score', y='Social support', data=hap)

# %%
plt.figure(figsize=(15, 10))
ax = sns.regplot(x='Happiness score', y='Social support', data=hap, color='green', marker='+')

# %%
plt.figure(figsize=(15, 10))
ax = sns.regplot(x='Happiness score', y='Perceptions of corruption', data=hap, color='red', marker='*')

# %%
df_cann=hap.iloc[:,:2]
df_cann
# Out:
#                                     Regional indicator  Happiness score
# Country name
# Finland                                 Western Europe           7.8087
# Denmark                                 Western Europe           7.6456
# Switzerland                             Western Europe           7.5599
# Iceland                                 Western Europe           7.5045
# Norway                                  Western Europe           7.4880
# Netherlands                             Western Europe           7.4489
# Sweden                                  Western Europe           7.3535
# New Zealand                      North America and ANZ           7.2996
# Austria                                 Western Europe           7.2942
# Luxembourg                              Western Europe           7.2375
# Canada                           North America and ANZ           7.2321
# Australia                        North America and ANZ           7.2228
# ...

# %%
df_continents = df_cann.groupby('Regional indicator', axis=0).mean().sort_values(by='Happiness score', ascending=False)

df_continents
# Out:
#                                     Happiness score
# Regional indicator
# North America and ANZ                      7.173525
# Western Europe                             6.899219
# Latin America and Caribbean                5.981786
# Central and Eastern Europe                 5.883818
# East Asia                                  5.714850
# Southeast Asia                             5.383367
# Commonwealth of Independent States         5.358342
# Middle East and North Africa               5.227159
# South Asia                                 4.475443
# Sub-Saharan Africa                         4.383495

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
print('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# Matplotlib version:  3.0.2

# %%
df_continents['Happiness score'].plot(kind='pie',
                            figsize=(10, 7),
                            autopct='%1.1f%%', # add in percentages
                            startangle=90,     # start angle 90° (Africa)
                            shadow=True,       # add shadow      
                            )

plt.title('Happiness score by Continent')
plt.axis('equal') # Sets the pie chart to look like a circle.

plt.show()

# %%
colors_list = ['crimson','teal','tomato','gold', 'yellowgreen', 'lightgreen', 'mediumseagreen', 'lightcoral', 'pink','thistle']
explode_list = [0.1, 0.1, 0.1, 0,0,0,0,0, 0, 0] # ratio for each continent with which to offset each wedge.

df_continents['Happiness score'].plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,         # turn off labels on pie chart
                            pctdistance=1.12,    # the ratio between the center of each pie slice and the start of the text generated by autopct 
                            colors=colors_list,  # add custom colors
                            explode=explode_list # 'explode' lowest 3 continents
                            )

# scale the title up by 12% to match pctdistance
plt.title('Happiness score by Region', y=1.12) 

plt.axis('equal') 


# add legend
plt.legend(labels=df_continents.index, loc='upper left') 

plt.show()

# %%
hap.sort_values(by='Happiness score', ascending=False).head()

# %%
last=hap.tail(1)
last

# %%
line=hap[:5]
line

# %%
dat=line.drop(columns=['Regional indicator','Ladder score'])
dat

# %% [markdown]
# ## Data Normalization

# %%
dat['Logged GDP per capita'] = dat['Logged GDP per capita']/dat['Logged GDP per capita'].max()
dat['Social support'] = dat['Social support']/dat['Social support'].max()
dat['Healthy life expectancy'] = dat['Healthy life expectancy']/dat['Healthy life expectancy'].max()
dat['Freedom to make life choices'] = dat['Freedom to make life choices']/dat['Freedom to make life choices'].max()
dat['Generosity'] = dat['Generosity']/dat['Generosity'].max()
dat['Perceptions of corruption'] = dat['Perceptions of corruption']/dat['Perceptions of corruption'].max()
dat

# %%
bar=dat[1:2]
bar

# %%
bar['Country name']='.'
bar

# %%
bar.plot(kind='barh', figsize=(10, 5), color=['lightcyan','paleturquoise','mediumturquoise','darkslategrey', 'darkcyan', 'cadetblue', 'teal'])

plt.title('Factors affecting Happiness score in Denamrk') # add title to the plot

            
plt.show()

# %%
lastt=last.drop(columns=['Regional indicator','Ladder score'])
lastt

# %%
lastt.plot(kind='barh', figsize=(10, 5), color=['lightcoral','indianred','brown','firebrick', 'maroon', 'darkred', 'red'])

plt.title('Factors affecting Happiness score in Afganistan') # add title to the plot

            
plt.show()

# %%
hap.head()
# Out:
#              Regional indicator  Happiness score  Logged GDP per capita  \
# Country name
# Finland          Western Europe           7.8087              10.639267
# Denmark          Western Europe           7.6456              10.774001
# Switzerland      Western Europe           7.5599              10.979933
# Iceland          Western Europe           7.5045              10.772559
# Norway           Western Europe           7.4880              11.087804
#
#               Social support  Healthy life expectancy  \
# Country name
# Finland             0.954330                71.900825
# Denmark             0.955991                72.402504
# Switzerland         0.942847                74.102448
# Iceland             0.974670                73.000000
# Norway              0.952487                73.200783
#
#               Freedom to make life choices  Generosity  \
# Country name
# Finland                           0.949172   -0.059482
# ...

# %%
hap['Logged GDP per capita'] = hap['Logged GDP per capita']/hap['Logged GDP per capita'].max()
hap['Social support'] = hap['Social support']/hap['Social support'].max()
hap['Healthy life expectancy'] = hap['Healthy life expectancy']/hap['Healthy life expectancy'].max()
hap['Freedom to make life choices'] = hap['Freedom to make life choices']/hap['Freedom to make life choices'].max()
hap['Generosity'] = hap['Generosity']/hap['Generosity'].max()
hap['Perceptions of corruption'] = hap['Perceptions of corruption']/hap['Perceptions of corruption'].max()

# %% [markdown]
# ## Model development

# %%
Z = hap[['Logged GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices','Generosity','Perceptions of corruption']]

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lm.fit(Z, hap['Happiness score'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lm.intercept_
# Out:
# -2.0593772352641526

# %%
lm.coef_
# Out:
# array([ 0.22907937,  2.72331804,  0.03530689,  1.77681502,  0.41056602,
#        -0.62816168])

# %%
Y_hat = lm.predict(Z)

# %%
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize=(12, 10))


ax1 = sns.distplot(hap['Happiness score'], hist=False, color="r", label="Actual Value")
sns.distplot(Y_hat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Happiness score')
plt.xlabel('Happiness score')
plt.ylabel('Factors affecting happiness')

plt.show()
plt.close()

# %%
from sklearn.metrics import mean_squared_error

# %%
lm.fit(Z, hap['Happiness score'])
# Find the R^2
print('The R-square is: ', lm.score(Z, hap['Happiness score']))
# Out:
# The R-square is:  0.7483323102875421

# %% [markdown]
# Splitting data into training and testing set

# %%
y_data = hap['Happiness score']

# %%
x_data=hap.drop('Happiness score',axis=1)

# %%
from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)


print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples : 16
# number of training samples: 137

# %%
from sklearn.linear_model import LinearRegression

# %%
hap.head(1)
# Out:
#              Regional indicator  Happiness score  Logged GDP per capita  \
# Country name
# Finland          Western Europe           7.8087              10.639267
#
#               Social support  Healthy life expectancy  \
# Country name
# Finland              0.95433                71.900825
#
#               Freedom to make life choices  Generosity  \
# Country name
# Finland                           0.949172   -0.059482
#
#               Perceptions of corruption
# Country name
# Finland                        0.195445

# %%
lr = LinearRegression()
lr.fit(x_train[['Logged GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']], y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
yhat_train = lr.predict(x_train[['Logged GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']])
yhat_train[0:5]
# Out:
# array([6.68320383, 4.52315853, 5.44946574, 5.78900665, 5.11120029])

# %%
yhat_test = lr.predict(x_test[['Logged GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']])
yhat_test[0:5]
# Out:
# array([5.72521472, 5.39496251, 5.207991  , 4.68573354, 5.79268866])

# %% [markdown]
# ## Model Evaluation

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))

    ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
    ax2 = sns.distplot(BlueFunction, hist=False, color="b", label=BlueName, ax=ax1)

    plt.title(Title)
    plt.xlabel('Happiness score')
    plt.ylabel('Factors affecting Happiness')

    plt.show()
    plt.close()

# %%
Title = 'Distribution  Plot of  Predicted Value Using Training Data vs Training Data Distribution'
DistributionPlot(y_train, yhat_train, "Actual Values (Train)", "Predicted Values (Train)", Title)

# %%
Title='Distribution  Plot of  Predicted Value Using Test Data vs Data Distribution of Test Data'
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",Title)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.45, random_state=0)

# %%
pr = PolynomialFeatures(degree=3)
x_train_pr = pr.fit_transform(x_train[['Logged GDP per capita']])
x_test_pr = pr.fit_transform(x_test[['Logged GDP per capita']])
pr
# Out:
# PolynomialFeatures(degree=3, include_bias=True, interaction_only=False)

# %%
poly = LinearRegression()
poly.fit(x_train_pr, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
yhat = poly.predict(x_test_pr)
yhat[0:5]
# Out:
# array([6.76881415, 4.19521331, 5.60057824, 4.56698096, 6.74211267])

# %%
print("Predicted values:", yhat[0:4])
print("True values:", y_test[0:4].values)
# Out:
# Predicted values: [6.76881415 4.19521331 5.60057824 4.56698096]
# True values: [6.40649986 4.18620014 5.77820015 4.84840012]

# %%
def PollyPlot(xtrain, xtest, y_train, y_test, lr,poly_transform):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))
    
    
    #training data 
    #testing data 
    # lr:  linear regression object 
    #poly_transform:  polynomial transformation object 
 
    xmax=max([xtrain.values.max(), xtest.values.max()])

    xmin=min([xtrain.values.min(), xtest.values.min()])

    x=np.arange(xmin, xmax, 0.1)


    plt.plot(xtrain, y_train, 'ro', label='Training Data')
    plt.plot(xtest, y_test, 'go', label='Test Data')
    plt.plot(x, lr.predict(poly_transform.fit_transform(x.reshape(-1, 1))), label='Predicted Function')
    plt.ylim([-10000, 60000])
    plt.ylabel('Happiness score')
    plt.legend()

# %%
PollyPlot(x_train[['Logged GDP per capita']], x_test[['Logged GDP per capita']], y_train, y_test, poly,pr)

# %%
poly.score(x_train_pr, y_train)
# Out:
# 0.6410103338261626

# %%
poly.score(x_test_pr, y_test)
# Out:
# 0.6194032973058136

# %%
Rsqu_test = []

order = [1, 2, 3, 4]
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train[['Logged GDP per capita']])
    
    x_test_pr = pr.fit_transform(x_test[['Logged GDP per capita']])    
    
    lr.fit(x_train_pr, y_train)
    
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
plt.text(3, 0.75, 'Maximum R^2 ')
# Out:
# Text(3, 0.75, 'Maximum R^2 ')
